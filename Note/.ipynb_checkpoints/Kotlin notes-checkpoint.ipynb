# %% [markdown]
# # ***Kotlin***

# %%
# 一，

---

## 🔴

> 

<br>

1、对象生命周期管理
-------------------------------

### 1️⃣

* 

### 2️⃣

* 

### 3️⃣

* 

<br>

---

1️⃣2️⃣3️⃣4️⃣5️⃣6️⃣7️⃣8️⃣9️⃣🔟🔴🟠🟡🟢🔵🟣🟤⚫⚪✅❌⚠️❗‼️

[emoji_website](https://www.emojiall.com/zh-hans/categories/I)
